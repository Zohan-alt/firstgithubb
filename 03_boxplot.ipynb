# %%
import seaborn
seaborn.set(style="whitegrid")
kashti= seaborn.load_dataset("titanic")
seaborn.boxplot(x="class", y="fare", data=kashti)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
import seaborn
import matlplotlib.pyplot as plt
seaborn.set(style="whitegrid")
tip= seaborn.load_dataset("tips")
tip
seaborn.boxplot(x="day", y="tip", data=tip, saturation=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 import seaborn
# ----> 2 import matlplotlib.pyplot as plt
#       3 seaborn.set(style="whitegrid")
#       4 tip= seaborn.load_dataset("tips")
#
# ModuleNotFoundError: No module named 'matlplotlib'

# %%
import seaborn as sns
import pandas as pf
import numpy as np

tip= seaborn.load_dataset("tips")
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn as sns
sns.set(style= "whitegrid")

tip= sns.load_dataset("tips")
sns.boxplot(y=tip["size"])
# Out:
# <Axes: ylabel='size'>

# %%
import seaborn as sns
sns.set(style= "whitegrid")

tip= sns.load_dataset("tips")
sns.boxplot(x="tip", y="day", hue="smoker", palette= "Set2", dodge=True, data=tip)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
sns.set(style= "whitegrid")

tip= sns.load_dataset("tips")
tip
sns.boxplot(x="day", y="tip",data=tip, color="#d11975")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

kashti= sns.load_dataset("titanic")
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import seaborn as sns
import pandas as pd
import numpy as np

kashti= sns.load_dataset("titanic")
sns.boxplot(x="survived",
           y="age",
           data=kashti)
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.boxplot(x="survived",
           y="age", showmeans=True,
           data=kashti)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 sns.boxplot(x="survived",
#       2            y="age", showmeans=True,
#       3            data=kashti)
# ----> 4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
kashti=sns.load_dataset("titanic")
sns.boxplot(x="survived",
           y="age", showmeans=True, 
            meanprops={"marker":"+", 
                       "markersize": "12", 
                       "markeredgecolor": "red"},
           data=kashti)
plt.xlabel("how many survived"),
plt.ylabel("age(years)"),
plt.title("Box plot of kitnay doobay or kitny bachye")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 12
#       5 kashti=sns.load_dataset("titanic")
#       6 sns.boxplot(x="survived",
#       7            y="age", showmeans=True,
#       8             meanprops={"marker":"+",
#       9                        "markersize": "12",
#      10                        "markeredgecolor": "red"},
#      11            data=kashti)
# ---> 12 plt.xlabel("how many survived"),
#      13 plt.ylabel("age(years)"),
#      14 plt.title("Box plot of kitnay doobay or kitny bachye")
#
# TypeError: 'str' object is not callable
